# %% [markdown]
# # 04 MultiVector Retriever
#
# To improve the retrieval effectiveness, in practice we can store multiple vectors per document. It's been proved in multiple use cases.
#
# LangChain provides a retriever component `MultiVectorRetriever` which support such mechanism. It can be implemented in the following methods:
#
# - Smaller Chunks
#
#   Split a document into smaller chunks, and embed them.
#
# - Summary
#
#   Create a summary for each document, embed that along with (or instead of) the document.
#
# - Hypothetical questions
#
#   Create hypothetical questions that each document would be appropriate to answer, embed those along with (or instead of) the document.

# %%
# !pip install langchain openai chromadb tiktoken pypdf
# Out:
# Requirement already satisfied: langchain in /home/aiton/anaconda3/lib/python3.9/site-packages (0.0.317)
# Requirement already satisfied: openai in /home/aiton/anaconda3/lib/python3.9/site-packages (0.28.1)
# Requirement already satisfied: chromadb in /home/aiton/anaconda3/lib/python3.9/site-packages (0.4.14)
# Requirement already satisfied: tiktoken in /home/aiton/anaconda3/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: pypdf in /home/aiton/anaconda3/lib/python3.9/site-packages (3.16.4)
# Requirement already satisfied: numpy<2,>=1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (1.26.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (3.8.5)
# Requirement already satisfied: requests<3,>=2 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (0.5.14)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.43 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (0.0.46)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (1.33)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.1)
# Requirement already satisfied: PyYAML>=5.3 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: anyio<4.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (3.7.1)
# Requirement already satisfied: pydantic<3,>=1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (1.10.12)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/aiton/anaconda3/lib/python3.9/site-packages (from langchain) (2.0.21)
# Requirement already satisfied: tqdm in /home/aiton/anaconda3/lib/python3.9/site-packages (from openai) (4.66.1)
# Requirement already satisfied: posthog>=2.4.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (3.0.2)
# Requirement already satisfied: fastapi>=0.95.2 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (0.104.0)
# Requirement already satisfied: grpcio>=1.58.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (1.58.0)
# Requirement already satisfied: overrides>=7.3.1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (1.16.1)
# Requirement already satisfied: typer>=0.9.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (0.13.3)
# Requirement already satisfied: pypika>=0.48.9 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (0.23.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (4.8.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (3.3.0)
# Requirement already satisfied: importlib-resources in /home/aiton/anaconda3/lib/python3.9/site-packages (from chromadb) (6.1.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/aiton/anaconda3/lib/python3.9/site-packages (from tiktoken) (2023.8.8)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/aiton/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (5.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/aiton/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /home/aiton/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (3.3)
# Requirement already satisfied: exceptiongroup in /home/aiton/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (1.1.3)
# Requirement already satisfied: sniffio>=1.1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (1.2.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/aiton/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: packaging>=17.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (21.3)
# Requirement already satisfied: flatbuffers in /home/aiton/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: sympy in /home/aiton/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.10.1)
# Requirement already satisfied: protobuf in /home/aiton/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (4.24.3)
# Requirement already satisfied: coloredlogs in /home/aiton/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/aiton/anaconda3/lib/python3.9/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (3.0.4)
# Requirement already satisfied: python-dateutil>2.1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.8.2)
# Requirement already satisfied: backoff>=1.10.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: monotonic>=1.5 in /home/aiton/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: six>=1.5 in /home/aiton/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: certifi in /home/aiton/anaconda3/lib/python3.9/site-packages (from pulsar-client>=3.1.0->chromadb) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.9)
# Requirement already satisfied: greenlet!=0.4.17 in /home/aiton/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (0.4.3)
# Requirement already satisfied: h11>=0.8 in /home/aiton/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: websockets>=10.4 in /home/aiton/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: watchfiles>=0.13 in /home/aiton/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.18.0)
# Requirement already satisfied: python-dotenv>=0.13 in /home/aiton/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/aiton/anaconda3/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/aiton/anaconda3/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.7.0)
# Requirement already satisfied: mpmath>=0.19 in /home/aiton/anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)

# %%
# !wget -O nvidia_10q_2023.pdf https://d18rn0p25nwr6d.cloudfront.net/CIK-0001045810/19771e6b-cc29-4027-899e-51a0c386111e.pdf
# Out:
# --2023-10-19 20:09:53--  https://d18rn0p25nwr6d.cloudfront.net/CIK-0001045810/19771e6b-cc29-4027-899e-51a0c386111e.pdf
# 正在解析主机 d18rn0p25nwr6d.cloudfront.net (d18rn0p25nwr6d.cloudfront.net)... 18.155.204.142, 18.155.204.120, 18.155.204.129, ...
# 正在连接 d18rn0p25nwr6d.cloudfront.net (d18rn0p25nwr6d.cloudfront.net)|18.155.204.142|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：458891 (448K) [application/pdf]
# 正在保存至: “nvidia_10q_2023.pdf”
#
# nvidia_10q_2023.pdf 100%[===================>] 448.14K   412KB/s  用时 1.1s
#
# 2023-10-19 20:09:56 (412 KB/s) - 已保存 “nvidia_10q_2023.pdf” [458891/458891])

# %%
import os
os.environ['OPENAI_API_KEY'] = "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"

# %%
from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.storage import InMemoryStore
from langchain.document_loaders import PyPDFLoader

# %%
loaders = [ PyPDFLoader('./nvidia_10q_2023.pdf') ]
docs = []
for l in loaders:
    docs.extend(l.load())
text_splitter = RecursiveCharacterTextSplitter(chunk_size=10000)
docs = text_splitter.split_documents(docs)

# %%
len(docs)
# Out:
# 51

# %%
print(docs[6])
# Out:
# page_content="NVIDIA CORPORATION AND SUBSIDIARIES\nCONDENSED CONSOLIDATED STATEMENTS OF SHAREHOLDERS’ EQUITY\nFOR THE SIX MONTHS ENDED JULY 30, 2023 AND JULY 31, 2022\n(Unaudited)\nCommon Stock\nOutstandingAdditional\nPaid-in\nCapitalAccumulated Other\nComprehensive LossRetained\nEarningsTotal\nShareholders'\nEquity (In millions, except per share data) Shares Amount\nBalances, January 29, 2023 2,466 $ 2 $ 11,971 $ (43) $ 10,171 $ 22,101 \nNet income — — — — 8,232 8,232 \nOther comprehensive loss — — — (8) — (8)\nIssuance of common stock from stock plans 14 — 247 — — 247 \nTax withholding related to vesting of restricted stock units (3) — (1,179) — — (1,179)\nShares repurchased (8) — (1) — (3,283) (3,284)\nCash dividends declared and paid ($0.08 per common share) — — — — (199) (199)\nStock-based compensation — — 1,591 — — 1,591 \nBalances, July 30, 2023 2,469 $ 2 $ 12,629 $ (51) $ 14,921 $ 27,501 \nBalances, January 30, 2022 2,506 $ 3 $ 10,385 $ (11) $ 16,235 $ 26,612 \nNet income — — — — 2,274 2,274 \nOther comprehensive loss — — — (79) — (79)\nIssuance of common stock from stock plans 15 — 205 — — 205 \nTax withholding related to vesting of restricted stock units (4) — (837) — — (837)\nShares repurchased (28) (1) (2) — (5,338) (5,341)\nCash dividends declared and paid ($0.08 per common share) — — — — (200) (200)\nStock-based compensation — — 1,217 — — 1,217 \nBalances, July 31, 2022 2,489 $ 2 $ 10,968 $ (90) $ 12,971 $ 23,851 \nSee accompanying Notes to Condensed Consolidated Financial Statements.\n7" metadata={'source': './nvidia_10q_2023.pdf', 'page': 6}

# %%
# The vectorstore to use to index the child chunks
vectorstore = Chroma(
    collection_name="full_documents",
    embedding_function=OpenAIEmbeddings()
)
# The storage layer for the parent documents
store = InMemoryStore()
id_key = "doc_id"
# The retriever (empty to start)
retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    docstore=store,
    id_key=id_key,
)
import uuid
doc_ids = [str(uuid.uuid4()) for _ in docs]

# %%
# The splitter to use to create smaller chunks
child_text_splitter = RecursiveCharacterTextSplitter(chunk_size=400)

# %%
sub_docs = []
for i, doc in enumerate(docs):
    _id = doc_ids[i]
    _sub_docs = child_text_splitter.split_documents([doc])
    for _doc in _sub_docs:
        _doc.metadata[id_key] = _id
    sub_docs.extend(_sub_docs)

# %%
print(doc_ids)
# Out:
# ['a18441ae-c055-4779-beed-06abc70302c2', 'bf0fcc26-3612-4913-bf5d-16f8b6b8bfe3', 'a871868f-4045-49f2-9a74-cfa1e2bddf29', 'd88b9dd7-d530-4ab7-9f5b-4da73520a796', 'db1b983c-8626-4f53-8445-cf54f8d21be3', '47acabdc-e30c-4eb5-b1b1-eb96fbae562c', '5437718b-9414-4008-b81e-7d602e094987', 'c7cb60e6-e6a5-4de1-a1d4-0b769fea4751', 'fa0f6bfa-a7b7-4890-8e49-6a50a3d780e1', 'b8be8d2a-3bbc-49df-a395-bcd3c4d4f75c', 'af906c9e-b9eb-4e9d-a1df-921381afe43d', 'd7e2dec4-75dd-4d87-9247-ef5b3ec21c1d', '29b488ad-33a5-495f-a6c7-9f3380e7c612', 'fc44e236-839e-4042-9f85-405d98544c9d', '64e81d25-8a8b-4768-a842-8e3857defe75', 'af47834d-2eb9-4c2a-9dce-75097d6495e3', '0d52302c-6300-4a9a-acf5-c1fe77e6ec75', '4c53e9c8-844f-4365-bd5c-64d0132a7561', '394fbd91-db87-4ec2-8675-4b5e399e70f1', '337ad6fc-635c-47ab-8cec-2c5a9fdcfd9c', '1764076c-5511-41e4-9f67-ff28b6a6b74f', '75a35c2f-e994-451c-93a7-6c5df17bf7c4', 'c24dee6a-4a20-494f-8ae0-e97e59b63c65', '2a87f1e0-1aa4-4501-a399-a50400a568c6', '06fbce28-0619-46c1-ac43-a96010b5bf97', '79c2f7b0-5628-4521-b452-776777ebf761', 'ef4615a4-652f-4b43-9fcf-b3155997200d', 'c88ad20c-f5e0-4b54-9cfe-aee96bee792d', '669b0a8f-4971-4b53-84fe-b6efac6e5280', '9537b9d7-655a-47f3-8dbe-5221e6b88c89', '3ca817df-41fe-43e9-b54c-67e7b32e93c0', '6dc3de9f-7ff9-4fa6-800f-f31659b87352', 'b9086367-c7b8-48d5-a3aa-2617497c09f8', '11781953-d40c-4077-8a30-09d74babedc6', '0bdc81af-73b4-4af0-a3db-5ac3ef3bd568', '0675a7e6-19b6-4d9e-8240-9b47fe8042f3', 'fb81a5f5-5da4-4b8f-8464-4ee12a400a97', '121ea686-4dc8-48f4-b2bb-69c713026221', '853914d2-137c-4d25-94b1-58feefde72f7', 'eeb2bb43-0737-4165-9022-9767d2574644', 'fdd214f3-ace2-4dad-996f-c3adf13719e8', '84ca9de2-6fcc-49e4-a0c5-cd001eb4a413', 'c190d202-cdfb-40f6-994a-931a9bc28e93', 'd625f815-f588-45b6-b7c7-7b535d38c8ba', 'a2ee6463-9c7a-4063-85c6-7fdea608c375', 'a6ef926d-858f-48e0-b77b-65cf1b49e9a4', 'e4e7af92-b98e-4123-9b94-9a2b85999258', '1251a9ee-c035-443d-a7f5-9b45bdfe3314', '6d914d89-0356-4579-856a-5e2ecf99a7b6', 'bca0ca29-a97f-4baa-94e1-72eb536d860f', 'f40c2b66-039b-4d1a-9053-841d30df87d0']

# %%
print(sub_docs)
# Out:
# [Document(page_content='UNITED ST ATES\nSECURITIES AND EXCHANGE COMMISSION\nWashington, D.C. 20549\nFORM 10-Q\n☒ QUARTERL Y REPORT PURSUANT T O SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\nFor the quarterly period ended July 30, 2023\nOR\n☐ TRANSITION REPORT PURSUANT T O SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\nCommission file number: 0-23985\nNVIDIA CORPORATION', metadata={'source': './nvidia_10q_2023.pdf', 'page': 0, 'doc_id': 'a18441ae-c055-4779-beed-06abc70302c2'}), Document(page_content='For the quarterly period ended July 30, 2023\nOR\n☐ TRANSITION REPORT PURSUANT T O SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\nCommission file number: 0-23985\nNVIDIA CORPORATION\n(Exact name of registrant as specified in its charter)\nDelaware 94-3177549\n(State or other jurisdiction of (I.R.S. Employer\nincorporation or organization) Identification No.)', metadata={'source': './nvidia_10q_2023.pdf', 'page': 0, 'doc_id': 'a18441ae-c055-4779-beed-06abc70302c2'}), Document(page_content="NVIDIA CORPORATION\n(Exact name of registrant as specified in its charter)\nDelaware 94-3177549\n(State or other jurisdiction of (I.R.S. Employer\nincorporation or organization) Identification No.)\n2788 San T omas Expressway , Santa Clara, California 95051\n(Address of principal executive offices) (Zip Code)\n(408) 486-2000\n(Registrant's telephone number, including area code)\nN/A", metadata={'source': './nvidia_10q_2023.pdf', 'page': 0, 'doc_id': 'a18441ae-c055-4779-beed-06abc70302c2'}), Document(page_content="2788 San T omas Expressway , Santa Clara, California 95051\n(Address of principal executive offices) (Zip Code)\n(408) 486-2000\n(Registrant's telephone number, including area code)\nN/A\n(Former name, former address and former fiscal year if changed since last report)\nSecurities registered pursuant to Section 12(b) of the Act:", metadata={'source': './nvidia_10q_2023.pdf', 'page': 0, 'doc_id': 'a18441ae-c055-4779-beed-06abc70302c2'}), Document(page_content="(Registrant's telephone number, including area code)\nN/A\n(Former name, former address and former fiscal year if changed since last report)\nSecurities registered pursuant to Section 12(b) of the Act:\nTitle of each class Trading Symbol(s) Name of each exchange on which registered\nCommon Stock, $0.001 par value per share NVDA The Nasdaq Global Select Market", metadata={'source': './nvidia_10q_2023.pdf', 'page': 0, 'doc_id': 'a18441ae-c055-4779-beed-06abc70302c2'}), Document(page_content='Title of each class Trading Symbol(s) Name of each exchange on which registered\nCommon Stock, $0.001 par value per share NVDA The Nasdaq Global Select Market\nIndicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during', metadata={'source': './nvidia_10q_2023.pdf', 'page': 0, 'doc_id': 'a18441ae-c055-4779-beed-06abc70302c2'}), Document(page_content='Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during\nthe preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for\nthe past 90 days. Yes ☒ No ☐', metadata={'source': './nvidia_10q_2023.pdf', 'page': 0, 'doc_id': 'a18441ae-c055-4779-beed-06abc70302c2'}), Document(page_content='the preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for\nthe past 90 days. Yes ☒ No ☐\nIndicate by check mark  whether the registrant has submitted electronically every Interactive  Data File required to be submitted pursuant to Rule 405 of', metadata={'source': './nvidia_10q_2023.pdf', 'page': 0, 'doc_id': 'a18441ae-c055-4779-beed-06abc70302c2'}), Document(page_content='the past 90 days. Yes ☒ No ☐\nIndicate by check mark   ...

# %%
print(sub_docs[1])
# Out:
# page_content='For the quarterly period ended July 30, 2023\nOR\n☐ TRANSITION REPORT PURSUANT T O SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\nCommission file number: 0-23985\nNVIDIA CORPORATION\n(Exact name of registrant as specified in its charter)\nDelaware 94-3177549\n(State or other jurisdiction of (I.R.S. Employer\nincorporation or organization) Identification No.)' metadata={'source': './nvidia_10q_2023.pdf', 'page': 0, 'doc_id': 'a18441ae-c055-4779-beed-06abc70302c2'}

# %%
retriever.vectorstore.add_documents(sub_docs)
retriever.docstore.mset(list(zip(doc_ids, docs)))

# %%
# Vectorstore alone retrieves the small chunks
similar_docs = retriever.vectorstore.similarity_search("What is the gross margin?")

# %%
similar_docs
# Out:
# [Document(page_content='Gross margin increased from a year ago and sequentially, primarily reflecting growth in Data Center sales. The year-on-year increase also\nreflects the impact on the year-ago gross margin from $1.34 billion in inventory provisions and related charges.\nOperating expenses were up 10% from a year ago and up 6% sequentially, primarily driven by compensation and benefits, including stock-based', metadata={'doc_id': 'ef4615a4-652f-4b43-9fcf-b3155997200d', 'page': 26, 'source': './nvidia_10q_2023.pdf'}),
#  Document(page_content='distributors, and channel partners. We expect this concentration trend will continue.\nGross Margin\nOur overall gross margin increased to 70.1% and 68.2% for the second quarter and first half of fiscal year 2024, respectively, from 43.5% and\n55.7% for the second quarter and first half of fiscal year 2023, respectively. The increase in the second quarter and first half of fiscal year 2024', metadata={'doc_id': '669b0a8f-4971-4b53-84fe-b6efac6e5280', 'page': 28, 'source': './nvidia_10q_2023.pdf'}),
#  Document(page_content='gross margin was an unfavorable impact of 3.6% and 2.8% in the second quarter and first half of fiscal year 2024, respectively.\nProvisions for inventory and excess inventory purchase obligations totaled $1.22 billion and $1.31 billion for the second quarter and first half of', metadata={'doc_id': '9537b9d7-655a-47f3-8dbe-5221e6b88c89', 'page': 29, 'source': './nvidia_10q_2023.pdf'}),
#  Document(page_content='percentage of revenue.\n Three Months Ended Six Months Ended\n July 30,\n2023July 31,\n2022July 30,\n2023July 31,\n2022\nRevenue 100.0 % 100.0 % 100.0 % 100.0 %\n     Cost of revenue 29.9 56.5 31.8 44.3 \nGross profit 70.1 43.5 68.2 55.7 \nOperating expenses    \n     Research and development 15.1 27.2 18.9 23.0 \n     Sales, general and administrative 4.7 8.8 6.1 7.9 \nAcquisition termination cost — — — 9.0', metadata={'doc_id': 'c88ad20c-f5e0-4b54-9cfe-aee96bee792d', 'page': 27, 'source': './nvidia_10q_2023.pdf'})]

# %%
relevant_docs = retriever.get_relevant_documents("What is the gross margin?")

# %%
len(relevant_docs)
# Out:
# 4

# %%
relevant_docs[0]
# Out:
# Document(page_content='Second Quarter of Fiscal Year 2024 Summary\nThree Months Ended\n July 30, 2023 April 30, 2023 July 31, 2022Quarter-over-Quarter\nChangeYear-over-Year\nChange\n($ in millions, except per share data)\nRevenue $ 13,507 $ 7,192 $ 6,704 88 % 101 %\nGross margin 70.1 % 64.6 % 43.5 % 5.5 pts 26.6 pts\nOperating expenses $ 2,662 $ 2,508 $ 2,416 6 % 10 %\nOperating income $ 6,800 $ 2,140 $ 499 218 % 1,263 %\nNet income $ 6,188 $ 2,043 $ 656 203 % 843 %\nNet income per diluted share $ 2.48 $ 0.82 $ 0.26 202 % 854 %\nWe specialize in markets where our computing platforms can provide tremendous acceleration for applications. These platforms incorporate\nprocessors, interconnects, software, algorithms, systems, and services to deliver unique value. Our platforms address four large markets where\nour expertise is critical: Data Center, Gaming, Professional Visualization, and Automotive.\nRevenue for the second quarter of fiscal year 2024 was $13.51 billion, up 101% from a year ago and up 88% sequentially.\nData Center revenue was up 171% from a year ago and up 141% sequentially, led by CSPs and large consumer internet companies. Strong\ndemand for the NVIDIA HGX platform based on our Hopper and Ampere GPU architectures was primarily driven by the development of large\nlanguage models and generative AI. Data Center Compute grew 195% from a year ago and 157% sequentially, largely reflecting the strong ramp\nof our Hopper-based HGX platform. Networking was up 94% from a year ago and up 85% sequentially, primarily on strong growth in InfiniBand\ninfrastructure to support our HGX platform. In the second quarter of fiscal year 2024, CSPs represented slightly more than half of our estimated\nData Center end demand, with large consumer internet companies being the next largest end demand, followed by enterprise and high\nperformance computing.\nGaming revenue was up 22% from a year ago and up 11% sequentially, primarily reflecting demand for our GeForce RTX 40 Series GPUs\nbased on the NVIDIA Ada Lovelace architecture following normalization of channel inventory levels.\nProfessional Visualization revenue was down 24% from a year ago and up 28% sequentially. The year-on-year decrease primarily reflects lower\nsell-in to partners following normalization of channel inventory levels. The sequential increase was primarily due to stronger enterprise\nworkstation demand and the ramp of NVIDIA RTX products based on the Ada Lovelace Architecture.\nAutomotive revenue was up 15% from a year ago and down 15% sequentially. The year-on-year increase was primarily driven by sales of self-\ndriving platforms. The sequential decrease primarily reflects lower overall auto demand, particularly in China.\nGross margin increased from a year ago and sequentially, primarily reflecting growth in Data Center sales. The year-on-year increase also\nreflects the impact on the year-ago gross margin from $1.34 billion in inventory provisions and related charges.\nOperating expenses were up 10% from a year ago and up 6% sequentially, primarily driven by compensation and benefits, including stock-based\ncompensation, reflecting growth in employees and compensation increases.\nMarket Platform Highlights\nData Center revenue for the second quarter of fiscal year 2024 was $10.32 billion, up 171% from a year ago. We announced that the NVIDIA\nGH200 Grace Hopper Superchip is available in the third quarter of fiscal year 2024; announced the NVIDIA L40S GPU - a universal data center\nprocessor for compute-intensive applications, including AI training and inference, is available now; unveiled the NVIDIA MGX server reference\ndesign; announced NVIDIA Spectrum-X, an accelerated networking platform for AI; and partnered with a\n27', metadata={'source': './nvidia_10q_2023.pdf', 'page': 26})

# %%
from langchain.memory import ConversationBufferMemory
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

# %%
from langchain.llms import OpenAI
from langchain.chains import ConversationalRetrievalChain
qa = ConversationalRetrievalChain.from_llm(OpenAI(temperature=0), retriever, memory=memory)

# %%
result = qa({"question": "What is the gross margin?"})

# %%
result
# Out:
# {'question': 'What is the gross margin?',
#  'chat_history': [HumanMessage(content='What is the gross margin?'),
#   AIMessage(content=' The gross margin was 70.1% for the second quarter of fiscal year 2024.')],
#  'answer': ' The gross margin was 70.1% for the second quarter of fiscal year 2024.'}

# %%
result = qa({"question": "What is the main contribution to it?"})
result
# Out:
# {'question': 'What is the main contribution to it?',
#  'chat_history': [HumanMessage(content='What is the gross margin?'),
#   AIMessage(content=' The gross margin was 70.1% for the second quarter of fiscal year 2024.'),
#   HumanMessage(content='What is the main contribution to it?'),
#   AIMessage(content=' Higher revenue from Compute GPUs of 208% and 112%, respectively, and lower inventory provisions.')],
#  'answer': ' Higher revenue from Compute GPUs of 208% and 112%, respectively, and lower inventory provisions.'}

# %% [markdown]
# ## Summary

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
import uuid
from langchain.schema.document import Document

# %%
chain = (
    {"doc": lambda x: x.page_content}
    | ChatPromptTemplate.from_template("Summarize the following document:\n\n{doc}")
    | ChatOpenAI(max_retries=0)
    | StrOutputParser()
)

# %%
pip install tenacity
# Out:
# Requirement already satisfied: tenacity in /home/aiton/anaconda3/lib/python3.9/site-packages (8.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai
from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
)  # for exponential backoff

# %%
import datetime

# %%
docss = docs[:2]

# %%
@retry(wait=wait_random_exponential(min=65, max=70), stop=stop_after_attempt(1))
def completion_with_backoff():
    i = datetime.datetime.now()  #获取当前时间
    print('今天是{}月{}日{}点{}分{}秒'.format(i.month,i.day,i.hour,i.minute,i.second))
    summaries = chain.batch(docs[:2], {"max_concurrency": 5})

# %%
len(docs)
# Out:
# 51

# %%
completion_with_backoff()
# Out:
# 今天是10月19日21点22分36秒
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# Input In [49], in completion_with_backoff()
#       4 print('今天是{}月{}日{}点{}分{}秒'.format(i.month,i.day,i.hour,i.minute,i.second))
# ----> 5 summaries = chain.batch(docs[:2], {"max_concurrency": 5})
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/schema/runnable/base.py:1255, in RunnableSequence.batch(self, inputs, config, return_exceptions, **kwargs)
#    1254         for i, step in enumerate(self.steps):
# -> 1255             inputs = step.batch(
#    1256                 inputs,
#    1257                 [
#    1258                     # each step a child run of the corresponding root run
#    1259                     patch_config(
#    1260                         config, callbacks=rm.get_child(f"seq:step:{i+1}")
#    1261                     )
#    1262                     for rm, config in zip(run_managers, configs)
#    1263                 ],
#    1264             )
#    1266 # finish the root runs
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/schema/runnable/base.py:311, in Runnable.batch(self, inputs, config, return_exceptions, **kwargs)
#     310 with get_executor_for_config(configs[0]) as executor:
# --> 311     return cast(List[Output], list(executor.map(invoke, inputs, configs)))
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:609, in Executor.map.<locals>.result_iterator()
#     608 if timeout is None:
# --> 609     yield fs.pop().result()
#     610 else:
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:446, in Future.result(self, timeout)
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     390 try:
# --> 391     raise self._exception
#     392 finally:
#     393     # Break a reference cycle with the exception in self._exception
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/schema/runnable/base.py:304, in Runnable.batch.<locals>.invoke(input, config)
#     303 else:
# --> 304     return self.invoke(input, config, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chat_models/base.py:149, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     144 config = config or {}
#     145 return cast(
#     146     BaseMessageChunk,
#     147     cast(
#     148         ChatGeneration,
# --> 149         self.generate_prompt(
#     150             [self._convert_input(input)],
#     151             stop=stop,
#     152             callbacks=config.get("callbacks"),
#     153             tags=config.get("tags"),
#     154             metadata=config.get("metadata"),
#     155             run_name=config.get("run_name"),
#     156             **kwargs,
#     157         ).generations[0][0],
#     158     ).message,
#     159 )
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chat_models/base.py:465, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     464 prompt_messages = [p.to_messages() for p in prompts]
# --> 465 return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chat_models/base.py:355, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     354             run_managers[i].on_llm_error(e)
# --> 355         raise e
#     356 flattened_outputs = [
#     357     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     358     for res in results
#     359 ]
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chat_models/base.py:345, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     343 try:
#     344     results.append(
# --> 345         self._generate_with_cache(
#     346             m,
#     347             stop=stop,
#     348             run_manager=run_managers[i] if run_managers else None,
#     349             **kwargs,
#     350         )
#     351     )
#     352 except BaseException as e:
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chat_models/base.py:498, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     497 if new_arg_supported:
# --> 498     return self._generate(
#     499         messages, stop=stop, run_manager=run_manager, **kwargs
#     500     )
#     501 else:
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chat_models/openai.py:360, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     359 params = {**params, **kwargs}
# --> 360 response = self.completion_with_retry(
#     361     messages=message_dicts, run_manager=run_manager, **params
#     362 )
#     363 return self._create_chat_result(response)
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chat_models/openai.py:299, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     297     return self.client.create(**kwargs)
# --> 299 return _completion_with_retry(**kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:325, in BaseRetrying.iter(self, retry_state)
#     324 if self.reraise:
# --> 325     raise retry_exc.reraise()
#     326 raise retry_exc from fut.exception()
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:158, in RetryError.reraise(self)
#     157 if self.last_attempt.failed:
# --> 158     raise self.last_attempt.result()
#     159 raise self
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     390 try:
# --> 391     raise self._exception
#     392 finally:
#     393     # Break a reference cycle with the exception in self._exception
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chat_models/openai.py:297, in ChatOpenAI.completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     295 @retry_decorator
#     296 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 297     return self.client.create(**kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      24 try:
# ---> 25     return super().create(*args, **kwargs)
#      26 except TryAgain as e:
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     140 (
#     141     deployment_id,
#     142     engine,
#    (...)
#     152     api_key, api_base, api_type, api_version, organization, **params
#     153 )
# --> 155 response, _, api_key = requestor.request(
#     156     "post",
#     157     url,
#     158     params=params,
#     159     headers=headers,
#     160     stream=stream,
#     161     request_id=request_id,
#     162     request_timeout=request_timeout,
#     163 )
#     165 if stream:
#     166     # must be an iterator
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py:299, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     289 result = self.request_raw(
#     290     method.lower(),
#     291     url,
#    (...)
#     297     request_timeout=request_timeout,
#     298 )
# --> 299 resp, got_stream = self._interpret_response(result, stream)
#     300 return resp, got_stream, self.api_key
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py:710, in APIRequestor._interpret_response(self, result, stream)
#     708 else:
#     709     return (
# --> 710         self._interpret_response_line(
#     711             result.content.decode("utf-8"),
#     712             result.status_code,
#     713             result.headers,
#     714             stream=False,
#     715         ),
#     716         False,
#     717     )
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py:775, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     774 if stream_error or not 200 <= rcode < 300:
# --> 775     raise self.handle_error_response(
#     776         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     777     )
#     778 return resp
#
# RateLimitError: Rate limit reached for gpt-3.5-turbo in organization org-JXHBc0XTJ18W533b9hr517mH on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 completion_with_backoff()
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:326, in BaseRetrying.iter(self, retry_state)
#     324     if self.reraise:
#     325         raise retry_exc.reraise()
# --> 326     raise retry_exc from fut.exception()
#     328 if self.wait:
#     329     sleep = self.wait(retry_state)
#
# RetryError: RetryError[<Future at 0x7f55906473d0 state=finished raised RateLimitError>]

# %%
# The vectorstore to use to index the child chunks
vectorstore = Chroma(
    collection_name="summaries",
    embedding_function=OpenAIEmbeddings()
)
# The storage layer for the parent documents
store = InMemoryStore()
id_key = "doc_id"
# The retriever (empty to start)
retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    docstore=store,
    id_key=id_key,
)
doc_ids = [str(uuid.uuid4()) for _ in docs]

# %%
summary_docs = [Document(page_content=s,metadata={id_key: doc_ids[i]}) for i, s in enumerate(summaries)]

# %%
retriever.vectorstore.add_documents(summary_docs)
retriever.docstore.mset(list(zip(doc_ids, docs)))

# %%
sub_docs = vectorstore.similarity_search("What is the gross margin?")
sub_docs[0]

# %%
retrieved_docs = retriever.get_relevant_documents("What is the gross margin?")
retrieved_docs[0]

# %%
qa = ConversationalRetrievalChain.from_llm(OpenAI(temperature=0), retriever, memory=ConversationBufferMemory(memory_key="chat_history", return_messages=True))

# %%
result = qa({"question": "What is the gross margin?"})
result

# %%
result = qa({"question": "What is the main contribution to it?"})
result

# %% [markdown]
# ## Hypothetical Questions

# %%
functions = [
    {
      "name": "hypothetical_questions",
      "description": "Generate hypothetical questions",
      "parameters": {
        "type": "object",
        "properties": {
          "questions": {
            "type": "array",
            "items": {
                "type": "string"
              },
          },
        },
        "required": ["questions"]
      }
    }
  ]

# %%
from langchain.output_parsers.openai_functions import JsonKeyOutputFunctionsParser
chain = (
    {"doc": lambda x: x.page_content}
    # Only asking for 3 hypothetical questions, but this could be adjusted
    | ChatPromptTemplate.from_template("Generate a list of 3 hypothetical questions that the below document could be used to answer:\n\n{doc}")
    | ChatOpenAI(max_retries=0, model="gpt-4").bind(functions=functions, function_call={"name": "hypothetical_questions"})
    | JsonKeyOutputFunctionsParser(key_name="questions")
)

# %%
hypothetical_questions = chain.batch(docs, {"max_concurrency": 5})

# %%
vectorstore = Chroma(
    collection_name="hypo-questions",
    embedding_function=OpenAIEmbeddings()
)
store = InMemoryStore()
id_key = "doc_id"
retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    docstore=store,
    id_key=id_key,
)
doc_ids = [str(uuid.uuid4()) for _ in docs]

# %%
question_docs = []
for i, question_list in enumerate(hypothetical_questions):
    question_docs.extend([Document(page_content=s,metadata={id_key: doc_ids[i]}) for s in question_list])

# %%
question_docs

# %%
retriever.vectorstore.add_documents(question_docs)
retriever.docstore.mset(list(zip(doc_ids, docs)))

# %%
qa = ConversationalRetrievalChain.from_llm(OpenAI(temperature=0), retriever, memory=ConversationBufferMemory(memory_key="chat_history", return_messages=True))

# %%
result = qa({"question": "What is the gross margin?"})
result

# %%
result = qa({"question": "What is the main contribution to it?"})
result
